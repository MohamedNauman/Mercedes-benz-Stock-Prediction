# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/content/MBG.DE.csv")

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2020-01-02  41.092484  41.845215  40.971882  41.566578  33.846729
# 1     2020-01-03  41.296261  41.362801  40.302322  40.813847  33.233799
# 2     2020-01-06  40.202515  40.593433  39.703465  40.593433  33.054317
# 3     2020-01-07  40.797215  41.208927  40.680767  40.917816  33.318455
# 4     2020-01-08  40.589275  41.167339  40.489468  41.146545  33.504704
# ...          ...        ...        ...        ...        ...        ...
# 1100  2024-04-24  74.150002  74.440002  73.769997  74.019997  74.019997
# 1101  2024-04-25  74.360001  74.360001  72.360001  73.220001  73.220001
# 1102  2024-04-26  73.639999  74.790001  73.260002  74.360001  74.360001
# 1103  2024-04-29  75.000000  75.279999  74.519997  74.790001  74.790001
# 1104  2024-04-30  73.209999  73.790001  70.410004  70.940002  70.940002
#
#        Volume
# 0     2973654
# 1     4014262
# 2     3441396
# 3     2816618
# 4     2659070
# ...

# %%
df.shape
# Out:
# (1105, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1105 non-null   object
#  1   Open       1105 non-null   float64
#  2   High       1105 non-null   float64
#  3   Low        1105 non-null   float64
#  4   Close      1105 non-null   float64
#  5   Adj Close  1105 non-null   float64
#  6   Volume     1105 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 60.6+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1105.000000  1105.000000  1105.000000  1105.000000  1105.000000
# mean     57.601284    58.280954    56.878953    57.592108    52.302903
# std      14.356715    14.382103    14.309748    14.356889    15.105935
# min      18.061396    19.225842    17.479174    18.165363    14.791645
# 25%      50.395580    52.060001    49.988022    50.619999    45.035072
# 50%      62.080002    62.730000    61.366329    62.031727    55.401306
# 75%      68.089996    68.650002    67.309998    67.978722    63.179527
# max      76.940002    77.900002    75.949997    76.610001    76.610001
#
#              Volume
# count  1.105000e+03
# mean   3.783187e+06
# std    2.648432e+06
# min    0.000000e+00
# 25%    2.178624e+06
# 50%    3.027640e+06
# 75%    4.398045e+06
# max    2.443688e+07

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df.head(10)
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2020-01-02  41.092484  41.845215  40.971882  41.566578  33.846729  2973654
# 1  2020-01-03  41.296261  41.362801  40.302322  40.813847  33.233799  4014262
# 2  2020-01-06  40.202515  40.593433  39.703465  40.593433  33.054317  3441396
# 3  2020-01-07  40.797215  41.208927  40.680767  40.917816  33.318455  2816618
# 4  2020-01-08  40.589275  41.167339  40.489468  41.146545  33.504704  2659070
# 5  2020-01-09  41.504196  41.712135  41.292103  41.321213  33.646935  3098476
# 6  2020-01-10  41.466770  41.508358  41.050896  41.113277  33.477615  3130777
# 7  2020-01-13  41.254673  41.254673  40.356388  40.668293  33.115273  3089806
# 8  2020-01-14  40.643341  40.897022  40.148449  40.302322  32.817272  4170529
# 9  2020-01-15  40.302322  40.306480  39.212734  39.291752  31.994387  5857810

# %%
df.tail(10)
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1095  2024-04-17  74.570000  75.209999  74.239998  74.400002  74.400002
# 1096  2024-04-18  74.809998  75.139999  74.449997  74.809998  74.809998
# 1097  2024-04-19  74.220001  74.349998  73.489998  74.139999  74.139999
# 1098  2024-04-22  74.879997  74.900002  73.360001  74.190002  74.190002
# 1099  2024-04-23  74.699997  74.779999  73.230003  74.050003  74.050003
# 1100  2024-04-24  74.150002  74.440002  73.769997  74.019997  74.019997
# 1101  2024-04-25  74.360001  74.360001  72.360001  73.220001  73.220001
# 1102  2024-04-26  73.639999  74.790001  73.260002  74.360001  74.360001
# 1103  2024-04-29  75.000000  75.279999  74.519997  74.790001  74.790001
# 1104  2024-04-30  73.209999  73.790001  70.410004  70.940002  70.940002
#
#        Volume
# 1095  1863829
# 1096  1799323
# 1097  2620156
# 1098  2146207
# 1099  2305021
# 1100  2223226
# 1101  2689932
# 1102  2632815
# 1103  2456200
# 1104  8393648

# %%
df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
from scipy import stats
z_scores=stats.zscore(df.select_dtypes(include=['float64','int64']))
z_scores
# Out:
# array([[-1.1504216 , -1.14330851, -1.11212818, -1.11673122, -1.2223362 ,
#         -0.30580356],
#        [-1.13622132, -1.17686636, -1.15893985, -1.16918491, -1.26293002,
#          0.08728908],
#        [-1.2124394 , -1.2303854 , -1.20080839, -1.18454435, -1.27481695,
#         -0.12911269],
#        ...,
#        [ 1.11766362,  1.14840803,  1.14526592,  1.16846248,  1.46082222,
#         -0.43455647],
#        [ 1.21243578,  1.18249344,  1.23335731,  1.19842683,  1.48930074,
#         -0.50127329],
#        [ 1.08769892,  1.07884569,  0.94601094,  0.93014152,  1.23431869,
#          1.74161464]])

# %%
df_outliers=df[(z_scores>3).any(axis=1)|(z_scores<-3).any(axis=1)]
print(f"The number of outlier rows:{df_outliers.shape[0]}")
# Out:
# The number of outlier rows:23

# %%
df_no_outliers=df[(z_scores<3).all(axis=1)&(z_scores>-3).all(axis=1)]
print(f"Number of rows after removing outliers:{df_no_outliers.shape[0]}")
# Out:
# Number of rows after removing outliers:1082

# %%
df['Close'].min()
# Out:
# 18.165363

# %%
df[df['Close']==df['Close'].min()]
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 55  2020-03-19  18.298445  19.225842  17.479174  18.165363  14.791645
#
#       Volume
# 55  13842283

# %%
df[df['Close']==df['Close'].max()]
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 1088  2024-04-08  75.050003  77.449997  75.040001  76.610001  76.610001
#
#        Volume
# 1088  4060772

# %%
df[df['Volume']==df['Volume'].min()]
# Out:
#            Date       Open       High        Low      Close  Adj Close  Volume
# 585  2022-04-21  65.349998  65.349998  65.349998  65.349998  56.003559       0
# 586  2022-04-22  65.099998  65.870003  64.730003  64.730003  55.472240       0
# 589  2022-04-27  62.910000  62.910000  62.910000  62.910000  53.912537       0
# 596  2022-05-06  61.000000  61.000000  61.000000  61.000000  56.484699       0
# 601  2022-05-13  63.509998  63.509998  63.509998  63.509998  58.808903       0
# 609  2022-05-25  63.709999  63.709999  63.709999  63.709999  58.994099       0
# 611  2022-05-27  65.199997  65.199997  65.199997  65.199997  60.373806       0
# 612  2022-05-30  65.199997  65.199997  65.199997  65.199997  60.373806       0
# 615  2022-06-02  67.300003  67.300003  67.300003  67.300003  62.318367       0
# 616  2022-06-03  67.300003  67.300003  67.300003  67.300003  62.318367       0
# 643  2022-07-12  53.580002  53.580002  53.580002  53.580002  49.613937       0
# ...

# %%
df[df['Volume']==df['Volume'].max()]
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 50  2020-03-12  24.436741  24.657152  20.864386  20.872702   16.99617
#
#       Volume
# 50  24436875

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df['Close'].min()
# Out:
# 18.165363

# %%
df['Close'].max()
# Out:
# 76.610001

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Close'],color='yellow')
plt.title('Box Plot of Closing price')
plt.xlabel('Closing Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Volume'],color='green')
plt.title('Box Plot of Volume')
plt.xlabel('Volume Traded in the day')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['High'],color='skyblue')
plt.title('Box Plot of High Price')
plt.xlabel('High Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Low'],color='orange')
plt.title('Box Plot of Low Price')
plt.xlabel('Low Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Open'],color='pink')
plt.title('Box Plot of Opening Price')
plt.xlabel('Opening Price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x=df['Adj Close'],color='ivory')
plt.title('Box Plot of Adjusted Close')
plt.xlabel('Adjusted Close')
plt.show()

# %%
sns.jointplot(x='Volume',y='Close',data=df_no_outliers,color='green')
plt.suptitle('Joint plot of Volume and Closing price')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df,x='Volume',shade=True,color='red')
plt.title('Kernel Density Estimation Plot of Volume')
plt.xlabel('Volume')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(data=df,x='Close',shade=True,color='blue')
plt.title('Kernel Density Estimation Plot of Closing Price')
plt.xlabel('Closing Price')
plt.ylabel('Density')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='Volume',y='Close',data=df_no_outliers,scatter_kws={'alpha':0.5},line_kws={'color':'red'})
plt.suptitle('Regression Plot of Volume and Closing Price')
plt.xlabel('Volume')
plt.ylabel('Closing Price')
plt.show()

# %%
df['Date']=pd.to_datetime(df['Date'])
plt.figure(figsize=(10,6))
plt.plot(df['Date'],df['Close'],label='Mercedes',color='red')
plt.title('Stock Price of Mercedes')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Date'],df['Volume'],label='Volume',color='green')
plt.title('Volume Traded of Mercedes')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(14,8))
plt.subplot(3,1,1)
sns.histplot(df['Open'],kde=True,color='blue',bins=30)
plt.title('Opening Price')
plt.xlabel('Opening Price')

plt.subplot(3,1,2)
sns.histplot(df['Close'],kde=True,color='red',bins=30)
plt.title('Closing Price')
plt.xlabel('Closing Price')

plt.subplot(3,1,3)
sns.histplot(df['Adj Close'],kde=True,color='green',bins=30)
plt.title('Adjusted Closing Price')
plt.xlabel('Adjusted Closing Price')
# Out:
# Text(0.5, 0, 'Adjusted Closing Price')

# %%
df['MA30'] = df['Close'].rolling(window=30).mean()
df['MA100'] = df['Close'].rolling(window=100).mean()

plt.figure(figsize=(14, 8))
plt.plot(df['Date'], df['Close'], label='Close Price', color='blue', alpha=0.6)
plt.plot(df['Date'], df['MA30'], label='30-day Moving Average', color='green', linestyle='--')
plt.plot(df['Date'], df['MA100'], label='100-day Moving Average', color='red', linestyle='--')
plt.title('Stock Price with 30-day and 100-day Moving Averages', fontsize=16)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price (USD)', fontsize=12)
plt.legend(loc='upper left')
plt.grid(True)
plt.show()

# %%
correlation_matrix=df[['Open','High','Low','Close','Adj Close','Volume']].corr()
correlation_matrix
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.999034  0.998981  0.997960   0.972386 -0.599096
# High       0.999034  1.000000  0.998774  0.999101   0.971738 -0.588599
# Low        0.998981  0.998774  1.000000  0.999051   0.974322 -0.609326
# Close      0.997960  0.999101  0.999051  1.000000   0.973696 -0.599344
# Adj Close  0.972386  0.971738  0.974322  0.973696   1.000000 -0.606198
# Volume    -0.599096 -0.588599 -0.609326 -0.599344  -0.606198  1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df_no_outliers)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error,r2_score

# %%
features=df.drop(columns=['Date','Close','MA30','MA100'])
target=df['Close']
X_train,X_test,y_train,y_test=train_test_split(features,target,test_size=0.2,random_state=29)
scaler=StandardScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
linear_model=LinearRegression()
linear_model.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
linear_pred=linear_model.predict(X_test_scaled)

# %%
linear_mae=mean_absolute_error(y_test,linear_pred)

# %%
print(f'Mean Absolute Error of Linear Regression Model:{linear_mae}')
# Out:
# Mean Absolute Error of Linear Regression Model:0.3317044737794331

# %%
linear_r2=r2_score(y_test,linear_pred)
print(f'R2 Score of Linear Regression Model:{linear_r2}')
# Out:
# R2 Score of Linear Regression Model:0.9989443541143219

# %%
dec_model=DecisionTreeRegressor()
dec_model.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeRegressor()

# %%
dec_model_pred=dec_model.predict(X_test_scaled)

# %%
dec_model_mae=mean_absolute_error(y_test,dec_model_pred)
print(f'Mean Absolute Error of Decision Tree Regression Model:{dec_model_mae}')
# Out:
# Mean Absolute Error of Decision Tree Regression Model:0.45531035746606324

# %%
dec_r2=r2_score(y_test,dec_model_pred)
print(f'R2 Score of Decision Tree Regression Model:{dec_r2}')
# Out:
# R2 Score of Decision Tree Regression Model:0.997634365340633

# %%
rf_model = RandomForestRegressor(n_estimators=250, random_state=42)

rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestRegressor(n_estimators=250, random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test_scaled)

y_pred_rf
# Out:
# array([70.020552  , 57.22261502, 38.47011694, 65.53820026, 62.85167417,
#        31.4866318 , 71.38844962, 64.04039131, 72.70406785, 48.80890318,
#        67.06965024, 62.6262524 , 38.32828678, 64.05195591, 66.00992281,
#        68.92258272, 62.62892587, 51.41806382, 67.67487996, 22.87044362,
#        59.60864091, 58.60890088, 40.61229906, 64.53952007, 66.3191939 ,
#        73.81538581, 61.33349221, 63.19879965, 30.94725962, 65.44057904,
#        22.9424894 , 59.05175373, 56.32515425, 63.74757674, 58.5848601 ,
#        39.60413769, 66.3122051 , 35.64819732, 65.17642272, 54.28567612,
#        58.20268352, 58.42254236, 62.52895579, 65.60612263, 55.07620056,
#        56.96971364, 64.97467291, 70.32984256, 61.90149783, 36.90646436,
#        71.1832528 , 69.93524001, 64.72549126, 58.75925569, 58.69689464,
#        60.09478688, 71.80149839, 40.92914505, 71.67294876, 72.49886291,
#        56.71202121, 32.9461325 , 71.24195662, 63.34135626, 64.09916774,
# ...

# %%
mae_rf = mean_absolute_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# %%
print(f'Mean Absolute Error of Random Forest Regression Model: {mae_rf}')
print(f'R2 Score of Random Forest Regression Model: {r2_rf}')
# Out:
# Mean Absolute Error of Random Forest Regression Model: 0.33131441951131
# R2 Score of Random Forest Regression Model: 0.998879408158934

# %%
xgb_model=XGBRegressor()
xgb_model.fit(X_train_scaled,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=None, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=None,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xgb_model_pred=xgb_model.predict(X_test_scaled)
xgb_model_pred
# Out:
# array([69.44957 , 57.04119 , 38.37175 , 65.83571 , 62.25149 , 31.603548,
#        71.090706, 64.17388 , 72.46322 , 48.683258, 67.35066 , 62.4219  ,
#        38.06423 , 63.99588 , 65.89064 , 69.003784, 62.751457, 51.170086,
#        67.808914, 22.660276, 59.51042 , 58.757416, 41.041843, 64.16887 ,
#        66.69666 , 73.926605, 61.51958 , 63.310192, 31.235111, 65.08799 ,
#        23.492931, 58.878414, 56.417667, 63.632954, 58.47436 , 38.90545 ,
#        66.07485 , 35.800583, 64.82827 , 54.20733 , 58.274715, 58.388573,
#        62.62229 , 65.68347 , 55.12486 , 56.74623 , 64.70479 , 70.384926,
#        61.90211 , 36.518986, 71.533516, 69.67526 , 64.605515, 58.798634,
#        58.81526 , 59.702747, 71.38775 , 40.446186, 71.54913 , 72.519485,
#        56.505016, 32.17123 , 71.27063 , 63.71773 , 64.05029 , 33.213127,
#        56.709   , 60.213074, 61.623096, 71.792915, 72.637924, 65.97455 ,
#        25.707827, 65.46291 , 61.390385, 63.320683, 74.38222 , 35.40396 ,
# ...

# %%
xgb_mae=mean_absolute_error(y_test,xgb_model_pred)
xgb_r2=r2_score(y_test,xgb_model_pred)

# %%
print(f'Mean Absolute Error of XGBoost Regression Model:{xgb_mae}')
print(f'R2 Score of XGBoost Regression Model:{xgb_r2}')
# Out:
# Mean Absolute Error of XGBoost Regression Model:0.3610260876658167
# R2 Score of XGBoost Regression Model:0.9987778568159504

# %%
print(f'Linear Regression Model - MAE: {linear_mae:.4f}, R2 Score: {linear_r2:.4f}')
print(f'Decision Tree Regression Model - MAE: {dec_model_mae:.4f}, R2 Score: {dec_r2:.4f}')
print(f'Random Forest Regression Model - MAE: {mae_rf:.4f}, R2 Score: {r2_rf:.4f}')
print(f'XGBoost Regression Model - MAE: {xgb_mae:.4f}, R2 Score: {xgb_r2:.4f}')
# Out:
# Linear Regression Model - MAE: 0.3317, R2 Score: 0.9989
# Decision Tree Regression Model - MAE: 0.4553, R2 Score: 0.9976
# Random Forest Regression Model - MAE: 0.3313, R2 Score: 0.9989
# XGBoost Regression Model - MAE: 0.3610, R2 Score: 0.9988

# %% [markdown]
# ### Model Performance Comparison
#
# Here's a summary of the performance metrics for each model:
#
# - **Linear Regression Model**:
#   - Mean Absolute Error (MAE): 0.3317
#   - R2 Score: 0.9989
#
# - **Decision Tree Regression Model**:
#   - Mean Absolute Error (MAE): 0.4462
#   - R2 Score: 0.9978
#
# - **Random Forest Regression Model**:
#   - Mean Absolute Error (MAE): 0.3313
#   - R2 Score: 0.9989
#
# - **XGBoost Regression Model**:
#   - Mean Absolute Error (MAE): 0.3610
#   - R2 Score: 0.9988
#
# **Analysis:**
#
# Both Linear Regression and Random Forest models show very similar and excellent performance, with MAE values around 0.33 and R2 scores of approximately 0.9989. These models have the lowest MAE and highest R2 scores among all tested models, indicating the best predictive accuracy and explanation of variance in the stock prices.
#
# XGBoost also performs well with an MAE of 0.3610 and an R2 of 0.9988, which is slightly lower than Linear Regression and Random Forest. The Decision Tree model, while still performing reasonably, has the highest MAE and lowest R2 score, making it the least accurate among the four.
#
# **Conclusion:**
#
# Based on these metrics, the **Linear Regression Model** and **Random Forest Regression Model** are the best-performing models for predicting stock prices in this scenario, as they achieved the lowest Mean Absolute Error and the highest R-squared score.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

model_names = ['Linear Regression', 'Decision Tree', 'Random Forest', 'XGBoost']
mae_scores = [linear_mae, dec_model_mae, mae_rf, xgb_mae]
r2_scores = [linear_r2, dec_r2, r2_rf, xgb_r2]

performance_df = pd.DataFrame({
    'Model': model_names,
    'MAE': mae_scores,
    'R2 Score': r2_scores
})

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

sns.barplot(x='Model', y='MAE', data=performance_df, ax=axes[0], palette='viridis')
axes[0].set_title('Model Performance: Mean Absolute Error (MAE)')
axes[0].set_ylabel('MAE')
axes[0].set_xticklabels(axes[0].get_xticklabels(), rotation=45, ha='right')

sns.barplot(x='Model', y='R2 Score', data=performance_df, ax=axes[1], palette='magma')
axes[1].set_title('Model Performance: R2 Score')
axes[1].set_ylabel('R2 Score')
axes[1].set_xticklabels(axes[1].get_xticklabels(), rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
sample_data = {
    'Open': [70.0],
    'High': [71.0],
    'Low': [69.5],
    'Adj Close': [69.8],
    'Volume': [3500000]
}
sample_input = pd.DataFrame(sample_data)
print(sample_input)
# Out:
#    Open  High   Low  Adj Close   Volume
# 0  70.0  71.0  69.5       69.8  3500000

# %%
sample_input_scaled = scaler.transform(sample_input)
print(sample_input_scaled)
# Out:
# [[ 0.84518585  0.86594777  0.86349801  1.13923691 -0.10908601]]

# %%
linear_pred_sample = linear_model.predict(sample_input_scaled)
rf_pred_sample = rf_model.predict(sample_input_scaled)

print(f"Predicted Close Price (Linear Regression): {linear_pred_sample[0]:.2f}")
print(f"Predicted Close Price (Random Forest): {rf_pred_sample[0]:.2f}")
# Out:
# Predicted Close Price (Linear Regression): 70.51
# Predicted Close Price (Random Forest): 70.07

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=linear_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title('Linear Regression: Actual vs. Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred_rf, alpha=0.6, color='green')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.title('Random Forest: Actual vs. Predicted Prices')
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.grid(True)
plt.show()

# %%
df_results = pd.DataFrame({'Date': df.loc[y_test.index, 'Date'], 'Actual': y_test, 'Predicted': linear_pred})
df_results = df_results.sort_values(by='Date').reset_index(drop=True)

plt.figure(figsize=(14, 7))
plt.plot(df_results['Date'], df_results['Actual'], label='Actual Close Price', color='blue')
plt.plot(df_results['Date'], df_results['Predicted'], label='Predicted Close Price (Linear Regression)', color='red', linestyle='--')
plt.title('Actual vs. Predicted Close Prices Over Time (Linear Regression)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
df_rf_results = pd.DataFrame({'Date': df.loc[y_test.index, 'Date'], 'Actual': y_test, 'Predicted': y_pred_rf})
df_rf_results = df_rf_results.sort_values(by='Date').reset_index(drop=True)

plt.figure(figsize=(14, 7))
plt.plot(df_rf_results['Date'], df_rf_results['Actual'], label='Actual Close Price', color='blue')
plt.plot(df_rf_results['Date'], df_rf_results['Predicted'], label='Predicted Close Price (Random Forest)', color='green', linestyle='--')
plt.title('Actual vs. Predicted Close Prices Over Time (Random Forest)')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_close_price_time_series(df):
    plt.figure(figsize=(10,6))
    plt.plot(df['Date'],df['Close'],label='Mercedes',color='red')
    plt.title('Stock Price of Mercedes')
    plt.xlabel('Date')
    plt.ylabel('Closing Price')
    plt.grid(True)
    return plt.gcf()

def plot_volume_time_series(df):
    plt.figure(figsize=(10,6))
    plt.plot(df['Date'],df['Volume'],label='Volume',color='green')
    plt.title('Volume Traded of Mercedes')
    plt.xlabel('Date')
    plt.ylabel('Volume')
    plt.grid(True)
    return plt.gcf()

def plot_moving_averages(df):
    plt.figure(figsize=(14, 8))
    plt.plot(df['Date'], df['Close'], label='Close Price', color='blue', alpha=0.6)
    plt.plot(df['Date'], df['MA30'], label='30-day Moving Average', color='green', linestyle='--')
    plt.plot(df['Date'], df['MA100'], label='100-day Moving Average', color='red', linestyle='--')
    plt.title('Stock Price with 30-day and 100-day Moving Averages', fontsize=16)
    plt.xlabel('Date', fontsize=12)
    plt.ylabel('Price (USD)', fontsize=12)
    plt.legend(loc='upper left')
    plt.grid(True)
    return plt.gcf()

def plot_boxplot(df, column, color):
    plt.figure(figsize=(10,6))
    sns.boxplot(x=df[column],color=color)
    plt.title(f'Box Plot of {column.replace("_", " ").title()}')
    plt.xlabel(f'{column.replace("_", " ").title()}')
    return plt.gcf()

def plot_kdeplot(df, column, color):
    plt.figure(figsize=(10,6))
    sns.kdeplot(data=df,x=column,shade=True,color=color)
    plt.title(f'Kernel Density Estimation Plot of {column.replace("_", " ").title()}')
    plt.xlabel(f'{column.replace("_", " ").title()}')
    plt.ylabel('Density')
    return plt.gcf()

def plot_histograms(df):
    plt.figure(figsize=(14,8))
    plt.subplot(3,1,1)
    sns.histplot(df['Open'],kde=True,color='blue',bins=30)
    plt.title('Opening Price')
    plt.xlabel('Opening Price')

    plt.subplot(3,1,2)
    sns.histplot(df['Close'],kde=True,color='red',bins=30)
    plt.title('Closing Price')
    plt.xlabel('Closing Price')

    plt.subplot(3,1,3)
    sns.histplot(df['Adj Close'],kde=True,color='green',bins=30)
    plt.title('Adjusted Closing Price')
    plt.xlabel('Adjusted Closing Price')
    plt.tight_layout()
    return plt.gcf()

def plot_correlation_heatmap(df):
    correlation_matrix=df[['Open','High','Low','Close','Adj Close','Volume']].corr()
    plt.figure(figsize=(10,6))
    sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',linewidths=0.5)
    plt.title('Correlation Matrix')
    return plt.gcf()

print("Plotting functions have been defined.")
# Out:
# Plotting functions have been defined.

# %%
def predict_price(Open: float, High: float, Low: float, Adj_Close: float, Volume: float) -> str:
    # Create a DataFrame from the input data
    input_data = pd.DataFrame({
        'Open': [Open],
        'High': [High],
        'Low': [Low],
        'Adj Close': [Adj_Close],
        'Volume': [Volume]
    })

    # Scale the input data using the pre-trained scaler
    input_scaled = scaler.transform(input_data)

    # Predict the Close price using the pre-trained Random Forest model
    predicted_close = rf_model.predict(input_scaled)[0]

    # Return the formatted prediction string
    return f"Predicted Close Price: ${predicted_close:.2f}"

print("The 'predict_price' function has been defined.")
# Out:
# The 'predict_price' function has been defined.

# %%
import gradio as gr

with gr.Blocks() as demo:
    gr.Markdown("# Stock Price Analysis Dashboard")

    with gr.Tab("Price Trends"):
        gr.Markdown("## Time Series Analysis of Stock Prices")
        gr.Plot(plot_close_price_time_series(df))
        gr.Plot(plot_volume_time_series(df))
        gr.Plot(plot_moving_averages(df))

    with gr.Tab("Distributions"):
        gr.Markdown("## Distribution Analysis of Key Metrics")
        gr.Plot(plot_boxplot(df, 'Close', 'yellow'))
        gr.Plot(plot_kdeplot(df, 'Close', 'blue'))
        gr.Plot(plot_histograms(df))

    with gr.Tab("Correlation Analysis"):
        gr.Markdown("## Feature Correlation Heatmap")
        gr.Plot(plot_correlation_heatmap(df))

    with gr.Tab("Prediction"):
        gr.Markdown("## Predict Stock Close Price using Random Forest Model")
        with gr.Row():
            open_price = gr.Number(label="Open Price")
            high_price = gr.Number(label="High Price")
            low_price = gr.Number(label="Low Price")
        with gr.Row():
            adj_close_price = gr.Number(label="Adj Close Price")
            volume_traded = gr.Number(label="Volume")

        predict_button = gr.Button("Predict Close Price")
        prediction_output = gr.Textbox(label="Prediction Result")

        predict_button.click(
            fn=predict_price,
            inputs=[
                open_price,
                high_price,
                low_price,
                adj_close_price,
                volume_traded
            ],
            outputs=prediction_output
        )

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f92838757596d3754e.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f92838757596d3754e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## Project Summary
#
# This project aimed to analyze and predict the closing stock prices of Mercedes (MBG.DE) using historical data. The key steps and findings are summarized below:
#
# ### 1. Data Loading and Initial Exploration
# - The historical stock data for MBG.DE was loaded from a CSV file into a pandas DataFrame.
# - Initial checks were performed to understand the data's shape, types, and basic statistics using `df.info()`, `df.describe()`, `df.head()`, and `df.tail()`.
# - Missing values and duplicate rows were checked and confirmed to be absent.
#
# ### 2. Outlier Detection and Handling
# - Outliers were identified using the Z-score method for numerical columns (`Open`, `High`, `Low`, `Close`, `Adj Close`, `Volume`).
# - A new DataFrame (`df_no_outliers`) was created by removing these identified outlier rows, resulting in 1082 rows remaining from an initial 1105.
#
# ### 3. Exploratory Data Analysis (EDA)
# - **Statistical Summaries**: Min/Max values for 'Close' and 'Volume' were identified.
# - **Box Plots**: Visualizations for 'Close', 'Volume', 'High', 'Low', 'Open', and 'Adj Close' revealed their distributions and potential outliers.
# - **Kernel Density Estimation (KDE) Plots**: KDE plots for 'Volume' and 'Close' illustrated the density distribution of these key metrics.
# - **Joint and Regression Plots**: A joint plot and a regression plot between 'Volume' and 'Close' (using the outlier-removed data) were generated to understand their relationship.
# - **Time Series Plots**: The historical trends of 'Close' price and 'Volume' over time were visualized.
# - **Moving Averages**: 30-day and 100-day Moving Averages were calculated and plotted against the 'Close' price to identify trends.
# - **Histograms**: Histograms for 'Open', 'Close', and 'Adj Close' provided insights into their frequency distributions.
# - **Correlation Analysis**: A heatmap of the correlation matrix for numerical features showed strong positive correlations among 'Open', 'High', 'Low', 'Close', and 'Adj Close', and a negative correlation with 'Volume'.
#
# ### 4. Model Training and Evaluation
# - The 'Date' column was converted to datetime objects.
# - Features (`Open`, `High`, `Low`, `Adj Close`, `Volume`) and the target variable (`Close`) were defined.
# - The data was split into training and testing sets (80/20 split).
# - `StandardScaler` was used to standardize the features.
# - Four regression models were trained and evaluated:
#     - **Linear Regression**
#     - **Decision Tree Regressor**
#     - **Random Forest Regressor**
#     - **XGBoost Regressor**
# - Model performance was assessed using Mean Absolute Error (MAE) and R2 Score.
#
# ### 5. Model Performance Comparison
# - **Linear Regression**: MAE: 0.3317, R2 Score: 0.9989
# - **Decision Tree Regression**: MAE: 0.4553, R2 Score: 0.9976
# - **Random Forest Regression**: MAE: 0.3313, R2 Score: 0.9989
# - **XGBoost Regression**: MAE: 0.3610, R2 Score: 0.9988
#
# - **Conclusion**: Both **Linear Regression** and **Random Forest Regression** models demonstrated excellent performance with very low MAE and high R2 scores, indicating strong predictive accuracy for the stock's closing price. The Random Forest model showed a slightly better MAE.
#
# ### 6. Interactive Prediction Tool
# - An interactive Gradio application was created, allowing users to input 'Open', 'High', 'Low', 'Adj Close', and 'Volume' prices to get a predicted 'Close' price using the best-performing Random Forest model.
# - The application also includes tabs for visualizing price trends, distributions, and correlation analysis.
